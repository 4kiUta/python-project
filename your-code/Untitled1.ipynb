# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.pylab as plt

def images(item):
    if(item["type"] == "piano"):
        ImageAddress = 'piano.jpg'
        ImageItself = Image.open(ImageAddress)
        plt.imshow(ImageNumpyFormat)
        ImageNumpyFormat = np.asarray(ImageItself)
        plt.imshow(ImageNumpyFormat)
        plt.axis('off')
        plt.draw()
        plt.pause(5) # pause how many seconds
        plt.close()  
        
        elif(item["type"] == "couch"):
            ImageAddress = 'couch.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()  
        
        elif(item["type"] == "queen bed"):
            ImageAddress = 'queen.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()  
        
        elif(item["type"] == "double bed"):
            ImageAddress = 'doublebed.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close() 
        
        elif(item["type"] == "dining table"):
            ImageAddress = 'diningtable.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close() 
        
        #elif(item["type"] == "door d"):
        #image = Image.open('doord.jpg')  #tentar colocar um git de festa
        #image.show()
# Out:
#   File "<ipython-input-1-b17f64b9091f>", line 18
#     elif(item["type"] == "couch"):
#        ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.pylab as plt

def images():
    for item in items:
        if item == "piano":
            ImageAddress = 'piano.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()  
        
        elif item == "couch"):
            ImageAddress = 'couch.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()  
        
        elif item == "queen bed"):
            ImageAddress = 'queen.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()  
        
        elif item == "double bed"):
            ImageAddress = 'doublebed.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close() 
        
        elif item == "dining table"):
            ImageAddress = 'diningtable.jpg'
            ImageItself = Image.open(ImageAddress)
            plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()

# %%
import sys

from PyQt4.QtGui import *

app = QApplication(sys.argv)

    
label = QLabel()
pixmap = QPixmap(sys.argv[1])
label.setPixmap(pixmap)
label.show()

sys.exit(app.exec_())

# %%
from PIL import Image

image = Image.open('unsplash_01.jpg')
image.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.pylab as plt


ImageAddress = 'unsplash_01.jpg'
ImageItself = Image.open(ImageAddress)
plt.imshow(ImageNumpyFormat)
ImageNumpyFormat = np.asarray(ImageItself)
plt.imshow(ImageNumpyFormat)
plt.axis('off')
plt.draw()
plt.pause(5) # pause how many seconds
plt.close()

# %%
#gif

from tkinter import *
import time
import os
root = Tk()

frames = [PhotoImage(file='mygif.gif',format = 'gif -index %i' %(i)) for i in range(100)]

def update(ind):

    frame = frames[ind]
    ind += 1
    label.configure(image=frame)
    root.after(100, update, ind)
label = Label(root)
label.pack()
root.after(0, update, 0)
root.mainloop()

# %%
 elif item == "door d"):
        image = Image.open('doord.jpg')  #tentar colocar um git de festa
        image.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.pylab as plt



def images(items):
    for item in items:
        if item == "piano":
            ImageAddress = 'piano.jpg'
            ImageItself = Image.open(ImageAddress)
            #plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()  
        
        elif item == "couch":
            ImageAddress = 'couch.jpg'
            ImageItself = Image.open(ImageAddress)
            #plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()  
        
        elif item == "queen bed":
            ImageAddress = 'queen.jpg'
            ImageItself = Image.open(ImageAddress)
            #plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close()  
        
        elif item == "double bed":
            ImageAddress = 'doublebed.jpg'
            ImageItself = Image.open(ImageAddress)
            #plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close() 
        
        elif item == "dining table":
            ImageAddress = 'diningtable.jpg'
            ImageItself = Image.open(ImageAddress)
            #plt.imshow(ImageNumpyFormat)
            ImageNumpyFormat = np.asarray(ImageItself)
            plt.imshow(ImageNumpyFormat)
            plt.axis('off')
            plt.draw()
            plt.pause(5) # pause how many seconds
            plt.close() 
        return
    
items=["piano", "couch", "queem bed"]

images(items)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.pylab as plt

def images(items):
    for item in items:
        if item == "piano":
            ImageAddress = 'piano.jpg'  
        
        elif item == "couch":
            ImageAddress = 'couch.jpg'
        
        elif item == "queen bed":
            ImageAddress = 'queen.jpg'
          
        elif item == "double bed":
            ImageAddress = 'doublebed.jpg'
        
        elif item == "dining table":
            ImageAddress = 'diningtable.jpg'
        
        ImageItself = Image.open(ImageAddress)
        ImageNumpyFormat = np.asarray(ImageItself)
        plt.imshow(ImageNumpyFormat)
        plt.imshow(ImageNumpyFormat)
        plt.axis('off')
        plt.draw()
        plt.pause(1) # pause how many seconds
        plt.close() 
        
    return
    
items=["piano", "couch", "queen bed"]

images(items)
